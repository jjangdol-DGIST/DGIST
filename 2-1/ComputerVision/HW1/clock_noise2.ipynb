# %%
from functions import *

from matplotlib import pyplot as plt

# %%
img_name = "clock_noise2.png"
    
msize = 3

im = Image.open(img_name)
col, row = im.size

cimg3d = np.array(im)
gimg2d = np.full((row,col),0)

# %%
color3dtogray2d(cimg3d,gimg2d) 
plt.imshow(gimg2d)
plt.show()

# %%
mask=np.full((msize,msize),1/(msize*msize)) # average mask

###
std = 2.0
hs=int(msize/2) # msize must be odd number 
for i in range(-hs,hs+1):
    for j in range(-hs,hs+1):
        mask[i+hs][j+hs] = (1.5/hs)*(1.0/(2*3.1416*std))*np.exp(-1.0*(i*i+j*j)/(2*std*std))        
#(1.5/hs) is an arbitaray constant for better visualizaiotion.
###

# %%
## sharpening
laplacian_mask1 = [[0, 1, 0],[1,-4,1],[0,1,0]] 
laplacian_mask2 = [[1, 1, 1],[1,-8,1],[1,1,1]] 
sobel_mask1 = [[-1, -2, -1],[0,0,0],[1,2,1]] 
sobel_mask2 = [[-1, 0, 1], [-2,0,2],[-1,0,1]] 
laplacian_mask3 = [[-1, -1, -1],[-1,8,-1],[-1,-1,-1]]

smaskx=[[-1,0,1],[-2,0,2],[-1,0,1]]
smasky=[[-1,-2,-1],[0,0,0],[1,2,1]]
lmask=[[0,1,0],[1,-4,1],[0,1,0]]
##

# %%
msize = 3
medianfiltering(gimg2d,msize)
plt.imshow(gimg2d)
plt.show()

# %%
for _ in range(3):
    maskfiltering(gimg2d,mask)
    plt.imshow(gimg2d)
    plt.show() 
    #다다익선?
    #30번 하니 보라화면..., 25동일
    #20번 이상은 에바인듯
    #13?
    #결국 5로 하기러

# %%
for _ in range(1):
    histonorm(gimg2d)
    plt.imshow(gimg2d)
    plt.show()
# # 3번째 이후부터는 무뎌지는 감이 들었음.
# # 앞의 과정을 20번 하니 5~6이 적당

# %%
maskfiltering(gimg2d,mask)
plt.imshow(gimg2d)
plt.show()

# %%
msize = 3
for _ in range(2):
    medianfiltering(gimg2d, msize)
    plt.imshow(gimg2d)
    plt.show()

# %%
for _ in range(1):
    maskfiltering(gimg2d,mask)
    plt.imshow(gimg2d)
    plt.show()

# %%
msize = 5
for _ in range(1):
    histonorm(gimg2d)
    medianfiltering(gimg2d, msize)
    plt.imshow(gimg2d)
    plt.show()
# #     #2번이 적당?

# %%
# for _ in range(3):
#     maskfiltering(gimg2d,mask)
#     plt.imshow(gimg2d)
#     plt.show()

# %%
# threshold = 100
# binarization(gimg2d, threshold)
# plt.imshow(gimg2d)
# plt.show()

# %%
# maskfiltering(gimg2d, laplacian_mask2)
# plt.imshow(gimg2d)
# plt.show()

# %%
gray2dtocolor3d(gimg2d,cimg3d)
plt.imshow(cimg3d)
plt.show()

# %%
out_img_name='result_clock2.png'#"out_average_mask"+str(msize)+img_name 
im2=Image.fromarray(cimg3d)
im2.save(out_img_name)
