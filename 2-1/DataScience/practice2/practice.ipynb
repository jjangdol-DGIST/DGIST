# %%
import io, csv, sys
import sys
import pandas as pd
import numpy as np
df['이동거리'] = df['이동거리'].astype(np.float64)

df = pd.read_csv('data_week.csv')

# %%
df.dropna(subset=['성별'], inplace=True)
df['성별'] = df['성별'].str.upper()

# temp = np.array(df['성별'].unique())

# %%
mean = df['이동거리'].mean()
std = df['이동거리'].std()
cutoff_lower = mean - std * 3
cutoff_upper = mean + std * 3

# %%
df = df[df['이동거리'] >= cutoff_lower]
df = df[df['이동거리'] <= cutoff_upper]

# %%
df
# Out:
#               대여일자  대여시간  대여소번호                        대여소명 대여구분코드 성별 연령대코드  \
# 134     2021-01-01     0   1952           1952. 천왕연지타운2단지 앞    정기권  F  ~10대
# 135     2021-01-01     0    828               828. 숙대입구역 8번    정기권  F   20대
# 136     2021-01-01     0   1047           1047. 건강보험 강동지사kt    정기권  F   20대
# 137     2021-01-01     0    112                112. 극동방송국 앞    정기권  F   20대
# 138     2021-01-01     0   2620          2620. 송파나루역 4번 출구옆    정기권  F   20대
# ...            ...   ...    ...                         ...    ... ..   ...
# 139068  2021-01-06    23   2189          2189.삼성서비스센터(관악점)     일일권  F   60대
# 139069  2021-01-06    23   2016         2016. 신대방삼거리역 3번출구쪽    일일권  M   20대
# 139070  2021-01-06    23    725             725. 양강중학교앞 교차로    일일권  M   20대
# 139071  2021-01-06    23   2220           2220. 반포본동 주민센터 앞    일일권  M   30대
# 139072  2021-01-06    23   2319  2319. 포스코사거리 서측(수협 삼성동 지점)    일일권  M   50대
#
#         이용건수    운동량   탄소량     이동거리  사용시간
# ...

# %%
print(df["이동거리"].describe())
# Out:
# count    76397.000000
# mean      1859.386324
# std       2461.977919
# min          0.000000
# 25%          0.000000
# 50%       1040.120000
# 75%       2482.840000
# max      13614.690000
# Name: 이동거리, dtype: float64
